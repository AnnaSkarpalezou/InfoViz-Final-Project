# %%
import pandas as pd
import requests
import io

# %%
#https://raw.githubusercontent.com/your-username/name-of-the-repository/master/name-of-the-file.csv
url = '/Users/annaskarpalezou/Desktop/InfoViz-Final-Project/iv-airbnb/public/data/listings.csv'

df = pd.read_csv(url)

# %%
df.head(15)
# Out:
#         id                                               name  host_id  \
# 0    24963                  Heart of French Concession / Home    98203
# 1    24991                    French Concession Yongkang area    98203
# 2   139828   【sidihome】The minimalist business apt In jing’an   681552
# 3   161932                Sublet 1BR in Shanghai July 1-Aug 1   774393
# 4   185736                    Apt in French Concession巨鹿路/富民路   891951
# 5   350728                  'Laojia' in the Heart of Shanghai  1777552
# 6   427038                 In the heart of French Concession.  2122588
# 7   479517                 有简约 绿色系 功能齐全 高楼层的绿色舒适7/13双轨交阳光暖窝公寓   681552
# 8   479530      【sidihome】ROSE  the big space apt in downtown   681552
# 9   496972  Free Airport pickup! Modern Stylish Master Bed...  2454164
# 10  519944     Puxiong Road, 10 minute taxi to Jing'an Temple  2131088
# 11  590810                Super Cool & Awesome LivingRm Couch  2454164
# 12  669100     Sime underground room Near  ECNU Jingan Temple  3387343
# 13  670684                Big, Clean, and Cozy Master Bedroom  2454164
# 14  674925                Near ECNU jingan Temp jiaotong Univ  3387343
#
#    host_name  neighbourhood_group             neighbourhood  latitude  \
# 0        Jia                  NaN      徐汇区 / Xuhui District  31.20918
# 1        Jia                  NaN      徐汇区 / Xuhui District  31.21095
# 2       Leon                  NaN      普陀区 / Putuo District  31.24399
# 3    Michael                  NaN    静安区 / Jing'an District  31.23101
# 4     Maggie                  NaN      徐汇区 / Xuhui District  31.21968
# 5      Nitin                  NaN  长宁区 / Changning District  31.22067
# 6        Mia                  NaN    黄浦区 / Huangpu District  31.21532
# 7       Leon                  NaN    静安区 / Jing'an District  31.24299
# 8       Leon                  NaN    静安区 / Jing'an District  31.24374
# 9      Alvin                  NaN     杨浦区 / Yangpu District  31.27859
# 10     Sammy                  NaN      普陀区 / Putuo District  31.23834
# 11     Alvin                  NaN    虹口区 / Hongkou District  31.27574
# 12      Lily                  NaN      普陀区 / Putuo District  31.23060
# 13     Alvin                  NaN    虹口区 / Hongkou District  31.27800
# 14      Lily                  NaN      普陀区 / Putuo District  31.23150
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0   121.45150  Entire home/apt    452               3                 85
# 1   121.45105  Entire home/apt    517               3                  1
# 2   121.44296  Entire home/apt    355               3                 26
# 3   121.42961  Entire home/apt    323              30                  0
# 4   121.44930     Private room    500               1                  8
# 5   121.43159     Private room    160               2                 85
# 6   121.46272     Private room    324               3                  0
# 7   121.44358  Entire home/apt    435               1                 69
# 8   121.44247  Entire home/apt    407               1                 33
# 9   121.49541     Private room    162               1                 79
# 10  121.41554     Private room    216               3                 14
# 11  121.49755      Shared room     78               1                 43
# 12  121.42007     Private room    127              10                 12
# 13  121.49134     Private room    160               1                  6
# 14  121.42138     Private room    199               2                 30
#
#    last_review  reviews_per_month  calculated_host_listings_count  \
# 0   2020-08-15               0.67                               2
# 1   2013-08-10               0.01                               2
# 2   2019-08-17               0.24                               7
# 3          NaN                NaN                               1
# 4   2017-09-05               0.15                               1
# 5   2020-09-04               0.79                               1
# 6          NaN                NaN                               1
# 7   2021-02-06               0.66                               7
# 8   2021-02-18               0.32                               7
# 9   2021-01-31               0.75                               5
# 10  2020-12-30               0.13                               1
# 11  2019-08-12               0.41                               5
# 12  2020-11-27               0.38                               2
# 13  2019-01-18               0.06                               5
# 14  2020-11-14               0.33                               2
#
#     availability_365
# 0                297
# 1                189
# 2                331
# 3                 89
# 4                364
# 5                 89
# 6                365
# 7                350
# 8                330
# 9                365
# 10               365
# 11               364
# 12               365
# 13               364
# 14               360

# %%
average_prices_by_nei = df.groupby('neighbourhood')
average_prices_by_nei = average_prices_by_nei[["price"]].mean()

# %%
average_prices_by_nei
# Out:
#                                 price
# neighbourhood
# 嘉定区 / Jiading District     513.509901
# 奉贤区 / Fengxian District    822.649819
# 宝山区 / Baoshan District     418.767551
# 崇明区 / Chongming District  1556.255352
# 徐汇区 / Xuhui District       648.912013
# 普陀区 / Putuo District       706.137681
# 杨浦区 / Yangpu District      382.054054
# 松江区 / Songjiang District  1019.591721
# 浦东新区 / Pudong              765.857534
# 虹口区 / Hongkou District     485.114165
# 金山区 / Jinshan District     694.351955
# 长宁区 / Changning District   686.513991
# 闵行区 / Minhang District     604.683211
# 青浦区 / Qingpu District     1159.491689
# 静安区 / Jing'an District     643.144334
# 黄浦区 / Huangpu District     714.264667

# %%
average_prices_by_nei.to_csv(r'/Users/annaskarpalezou/Desktop/InfoViz-Final-Project/iv-airbnb/public/data/av_prices.csv', index = True)

# %%
neighbourhoods = list(df.groupby('neighbourhood').groups.keys())
c
# Out:
# ['嘉定区 / Jiading District',
#  '奉贤区 / Fengxian District',
#  '宝山区 / Baoshan District',
#  '崇明区 / Chongming District',
#  '徐汇区 / Xuhui District',
#  '普陀区 / Putuo District',
#  '杨浦区 / Yangpu District',
#  '松江区 / Songjiang District',
#  '浦东新区 / Pudong',
#  '虹口区 / Hongkou District',
#  '金山区 / Jinshan District',
#  '长宁区 / Changning District',
#  '闵行区 / Minhang District',
#  '青浦区 / Qingpu District',
#  "静安区 / Jing'an District",
#  '黄浦区 / Huangpu District']

# %%
stats_by_nei = df.groupby('neighbourhood')
n_listings_pernei = stats_by_nei[['host_id']].count()
n_listings_pernei
# Out:
#                           host_id
# neighbourhood
# 嘉定区 / Jiading District        808
# 奉贤区 / Fengxian District       277
# 宝山区 / Baoshan District        641
# 崇明区 / Chongming District     1308
# 徐汇区 / Xuhui District         3671
# 普陀区 / Putuo District          828
# 杨浦区 / Yangpu District         888
# 松江区 / Songjiang District     1232
# 浦东新区 / Pudong               13877
# 虹口区 / Hongkou District        946
# 金山区 / Jinshan District        179
# 长宁区 / Changning District     1358
# 闵行区 / Minhang District       2317
# 青浦区 / Qingpu District        1143
# 静安区 / Jing'an District       2321
# 黄浦区 / Huangpu District       4500

# %%
room_type_by_nei = df.groupby(['neighbourhood','room_type'])[['id']].count()
room_type_by_nei
# Out:
#                                             id
# neighbourhood            room_type
# 嘉定区 / Jiading District   Entire home/apt   507
#                          Private room      282
#                          Shared room        19
# 奉贤区 / Fengxian District  Entire home/apt   200
#                          Private room       72
#                          Shared room         5
# 宝山区 / Baoshan District   Entire home/apt   336
#                          Private room      285
#                          Shared room        20
# 崇明区 / Chongming District Entire home/apt   647
#                          Private room      658
#                          Shared room         3
# 徐汇区 / Xuhui District     Entire home/apt  2827
#                          Private room      711
#                          Shared room       133
# 普陀区 / Putuo District     Entire home/apt   434
#                          Private room      340
#                          Shared room        54
# 杨浦区 / Yangpu District    Entire home/apt   510
#                          Private room      343
#                          Shared room        35
# 松江区 / Songjiang District Entire home/apt   846
#                          Private room      366
#                          Shared room        20
# 浦东新区 / Pudong            Entire home/apt  5353
#                          Hotel room          2
#                          Private room     8375
#                          Shared room       147
# 虹口区 / Hongkou District   Entire home/apt   636
#                          Private room      272
#                          Shared room        38
# 金山区 / Jinshan District   Entire home/apt    58
#                          Private room      121
# 长宁区 / Changning District Entire home/apt   801
#                          Private room      485
#                          Shared room        72
# 闵行区 / Minhang District   Entire home/apt  1668
#                          Private room      615
#                          Shared room        34
# 青浦区 / Qingpu District    Entire home/apt   564
#                          Private room      559
#                          Shared room        20
# 静安区 / Jing'an District   Entire home/apt  1547
#                          Private room      580
#                          Shared room       194
# 黄浦区 / Huangpu District   Entire home/apt  3588
#                          Private room      720
#                          Shared room       192

# %%
new_df = pd.DataFrame({'n of Entire home/apts':room_type_by_nei['id'].iloc[::3].values, 'n of Private rooms':room_type_by_nei['id'].iloc[1::3].values, 'n of Shared rooms':room_type_by_nei['id'].iloc[2::3].values}, index = neighbourhoods)
new_df
# Out:
#                           n of Entire home/apts  n of Private rooms  \
# 嘉定区 / Jiading District                      507                 282
# 奉贤区 / Fengxian District                     200                  72
# 宝山区 / Baoshan District                      336                 285
# 崇明区 / Chongming District                    647                 658
# 徐汇区 / Xuhui District                       2827                 711
# 普陀区 / Putuo District                        434                 340
# 杨浦区 / Yangpu District                       510                 343
# 松江区 / Songjiang District                    846                 366
# 浦东新区 / Pudong                              5353                   2
# 虹口区 / Hongkou District                      147                 636
# 金山区 / Jinshan District                       38                  58
# 长宁区 / Changning District                    801                 485
# 闵行区 / Minhang District                     1668                 615
# 青浦区 / Qingpu District                       564                 559
# 静安区 / Jing'an District                     1547                 580
# 黄浦区 / Huangpu District                     3588                 720
#
#                           n of Shared rooms
# 嘉定区 / Jiading District                   19
# 奉贤区 / Fengxian District                   5
# 宝山区 / Baoshan District                   20
# 崇明区 / Chongming District                  3
# 徐汇区 / Xuhui District                    133
# 普陀区 / Putuo District                     54
# 杨浦区 / Yangpu District                    35
# 松江区 / Songjiang District                 20
# 浦东新区 / Pudong                          8375
# 虹口区 / Hongkou District                  272
# 金山区 / Jinshan District                  121
# 长宁区 / Changning District                 72
# 闵行区 / Minhang District                   34
# 青浦区 / Qingpu District                    20
# 静安区 / Jing'an District                  194
# 黄浦区 / Huangpu District                  192

# %%
#room_type_by_nei[room_type_by_nei['room_type']=='Entire home/apt'].count()

# %%
stats_by_nei = df.groupby('neighbourhood')
max_price = stats_by_nei[['price']].max()
min_price = stats_by_nei[['price']].min()
max_price.columns = ["maximum price"]
min_price.columns = ["minimum price"]
average_prices_by_nei.columns = ["Average Price"]
max_price


reviews_per_month = stats_by_nei[['reviews_per_month']].mean()
reviews_per_month.columns = ["Mean n of reviews per month"]

# %%
by_nei = pd.concat([average_prices_by_nei,max_price,min_price,new_df, reviews_per_month],axis=1)
by_nei
# Out:
#                           Average Price  maximum price  minimum price  \
# 嘉定区 / Jiading District       513.509901          67033              0
# 奉贤区 / Fengxian District      822.649819          11000             40
# 宝山区 / Baoshan District       418.767551          11372             16
# 崇明区 / Chongming District    1556.255352          39800             75
# 徐汇区 / Xuhui District         648.912013          75771             50
# 普陀区 / Putuo District         706.137681          69489             68
# 杨浦区 / Yangpu District        382.054054           9999             59
# 松江区 / Songjiang District    1019.591721          25000              0
# 浦东新区 / Pudong                765.857534          68000              0
# 虹口区 / Hongkou District       485.114165          20800             64
# 金山区 / Jinshan District       694.351955           5254             66
# 长宁区 / Changning District     686.513991          70665             59
# 闵行区 / Minhang District       604.683211          70313             32
# 青浦区 / Qingpu District       1159.491689          60571              0
# 静安区 / Jing'an District       643.144334          70780             52
# 黄浦区 / Huangpu District       714.264667          66666             49
#
#                           n of Entire home/apts  n of Private rooms  \
# 嘉定区 / Jiading District                      507                 282
# 奉贤区 / Fengxian District                     200                  72
# 宝山区 / Baoshan District                      336                 285
# 崇明区 / Chongming District                    647                 658
# 徐汇区 / Xuhui District                       2827                 711
# 普陀区 / Putuo District                        434                 340
# 杨浦区 / Yangpu District                       510                 343
# 松江区 / Songjiang District                    846                 366
# 浦东新区 / Pudong                              5353                   2
# 虹口区 / Hongkou District                      147                 636
# 金山区 / Jinshan District                       38                  58
# 长宁区 / Changning District                    801                 485
# 闵行区 / Minhang District                     1668                 615
# 青浦区 / Qingpu District                       564                 559
# 静安区 / Jing'an District                     1547                 580
# 黄浦区 / Huangpu District                     3588                 720
#
#                           n of Shared rooms  Mean n of reviews per month
# 嘉定区 / Jiading District                   19                     0.560153
# 奉贤区 / Fengxian District                   5                     0.465245
# 宝山区 / Baoshan District                   20                     0.592405
# 崇明区 / Chongming District                  3                     0.451656
# 徐汇区 / Xuhui District                    133                     1.008089
# 普陀区 / Putuo District                     54                     0.747010
# 杨浦区 / Yangpu District                    35                     0.710717
# 松江区 / Songjiang District                 20                     0.704169
# 浦东新区 / Pudong                          8375                     0.964121
# 虹口区 / Hongkou District                  272                     1.086034
# 金山区 / Jinshan District                  121                     0.361222
# 长宁区 / Changning District                 72                     0.841431
# 闵行区 / Minhang District                   34                     0.640151
# 青浦区 / Qingpu District                    20                     0.507700
# 静安区 / Jing'an District                  194                     1.019391
# 黄浦区 / Huangpu District                  192                     1.297110

# %%
by_nei.to_csv(r'/Users/annaskarpalezou/Desktop/InfoViz-Final-Project/iv-airbnb/public/data/tooltip_stats.csv', index = True)
